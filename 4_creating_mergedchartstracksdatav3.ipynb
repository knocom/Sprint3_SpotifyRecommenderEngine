# %%
import pandas as pd

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/knocom/Sprint3_SpotifyRecommenderEngine/main/merged_charts_tracks_datav2.csv')

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/knocom/Sprint3_SpotifyRecommenderEngine/main/spotify_daily_charts_tracks_predicted_genres.csv")

# %%
df1.head()
# Out:
#          date  position                track_id   track_name  streams  \
# 0  2019-09-01         1  6IdEQ3HUseBeRUYFSzSMdL     Zebbiana   267548
# 1  2019-09-01         2  6v3KW9xbzN5yKLt9YKDYA2     Señorita   259828
# 2  2019-09-01         3  1dGr1c8CrMLDpV6mPbImSI        Lover   240408
# 3  2019-09-01         4  0gDRtumoR9ZrvAlnniToMz  Ikaw At Ako   236726
# 4  2019-09-01         5  5l9g7py8RCblcvbZgGQgSd    Pagtingin   190049
#
#                 artist_id       artist_name                album_id  duration  \
# 0  117XFtbZPnCI1EYKjYZWJc       Skusta Clee  4AaygWd1ZnCzZ4ak9EM23s    304664
# 1  7n2wHs1TKAczGzO7Dd2rGr      Shawn Mendes  0xzScN8P3hQAz3BT3YYX5w    190799
# 2  06HL4z0CvFAxyc27GXpf02      Taylor Swift  1NAmidJlEaVgA3MpcPFYGq    221306
# 3  0rZRTXEmmPmx6gt92tBqIc  Moira Dela Torre  397zfeJ75BlnjfUEkgtwlG    269876
# 4  4DAcJXcjX0zlQAZAPAx4Zb           Ben&Ben  7xCcuTA3abKwxj8HwgxP7R    227370
#
#   release_date  ...  mode  speechiness  acousticness  instrumentalness  \
# ...

# %%
df2.head()
# Out:
#                  track_id             track_name               artist_id  \
# 0  7k4t7uLgtOxPwTpFmtJNTY                   Tusa  790FomKkXshlbRYZFtlgla
# 1  6EDO9iiTtwNv6waLwa1UUq  POPSTAR (feat. Drake)  0QHgL1lAIqAw0HtD7YldmP
# 2  55CHeLEfn5iJ0IIkgaa4si                 Savage  181bsRPaVXVlUKXrxwZfHK
# 3  6Ozh9Ok6h4Oi1wUSLtBseN                    BOP  4r63FhuTkUYltbVAg5TQnk
# 4  6EOKwHETwSkZ9gW2b6ASE0                 Ransom  4Ga1P7PMIsmqEZqhYZQgDo
#
#            artist_name                album_id  duration release_date  \
# 0              KAROL G  7mKevNHhVnZER3BLgI8O4F    200960   2019-11-07
# 1            DJ Khaled  5nNtpPsSUgb9Hlb3dF1gXa    200221   2020-07-17
# 2  Megan Thee Stallion  6Lo6ylJg4qbFfxicPEOzMI    155497   2020-03-06
# 3               DaBaby  1NsTSXjVNE7XmZ8PmyW0wl    159714   2019-09-27
# 4            Lil Tecca  65T18oWoikW2MAilg9j8lW    131240   2019-08-30
#
#    popularity  danceability  energy  ...  predicted_genre_id  predicted_genre  \
# ...

# %%
#19:28

# %%
df3 = df2.drop(['track_name', 'artist_id', 'artist_name', 'album_id',
       'duration', 'release_date', 'popularity', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo'], axis=1)

# %%
df2.columns
# Out:
# Index(['track_id', 'track_name', 'artist_id', 'artist_name', 'album_id',
#        'duration', 'release_date', 'popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo',
#        'predicted_genre_id', 'predicted_genre', 'predicted_genre_prob',
#        'predicted_classical_prob', 'predicted_country_prob',
#        'predicted_electronic_prob', 'predicted_folk_prob',
#        'predicted_hiphoprapcons_prob', 'predicted_jazz_prob',
#        'predicted_rock_prob'],
#       dtype='object')

# %%
df3
# Out:
#                     track_id  predicted_genre_id predicted_genre  \
# 0     7k4t7uLgtOxPwTpFmtJNTY                   4   hiphoprapcons
# 1     6EDO9iiTtwNv6waLwa1UUq                   4   hiphoprapcons
# 2     55CHeLEfn5iJ0IIkgaa4si                   4   hiphoprapcons
# 3     6Ozh9Ok6h4Oi1wUSLtBseN                   4   hiphoprapcons
# 4     6EOKwHETwSkZ9gW2b6ASE0                   4   hiphoprapcons
# ...                      ...                 ...             ...
# 1056  6xRNqXP3baPR9buXr8vreM                   1         country
# 1057  1ODZGydlown4VesUP8HLJX                   1         country
# 1058  0tgVpDi06FyKpA1z0VMD4v                   3            folk
# 1059  6Ha8pqxdSJHdPY4tlzPhlT                   2      electronic
# 1060  62aP9fBQKYKxi7PDXwcUAS                   2      electronic
#
#       predicted_genre_prob  predicted_classical_prob  predicted_country_prob  \
# 0                 1.000000                  0.000000                0.000000
# ...

# %%
df3[df3['track_id']=='7ytR5pFWmSjzHJIeQkgog4']
# Out:
#                   track_id  predicted_genre_id predicted_genre  \
# 55  7ytR5pFWmSjzHJIeQkgog4                   4   hiphoprapcons
#
#     predicted_genre_prob  predicted_classical_prob  predicted_country_prob  \
# 55              0.714286                       0.0                0.171429
#
#     predicted_electronic_prob  predicted_folk_prob  \
# 55                        0.0             0.028571
#
#     predicted_hiphoprapcons_prob  predicted_jazz_prob  predicted_rock_prob
# 55                      0.714286             0.057143             0.028571

# %%
df1.dtypes
# Out:
# date                 object
# position              int64
# track_id             object
# track_name           object
# streams               int64
# artist_id            object
# artist_name          object
# album_id             object
# duration              int64
# release_date         object
# popularity            int64
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# is_mainstay           int64
# is_Top100             int64
# is_viral              int64
# dtype: object

# %%
df3.dtypes
# Out:
# track_id                         object
# predicted_genre_id                int64
# predicted_genre                  object
# predicted_genre_prob            float64
# predicted_classical_prob        float64
# predicted_country_prob          float64
# predicted_electronic_prob       float64
# predicted_folk_prob             float64
# predicted_hiphoprapcons_prob    float64
# predicted_jazz_prob             float64
# predicted_rock_prob             float64
# dtype: object

# %%
df4 = df1.set_index('track_id').join(df3.set_index('track_id'))

# %%
df4
# Out:
#                               date  position                    track_name  \
# track_id
# 00mBzIWv5gHOYxwuEJXjOG  2019-09-01        38         Sa Ngalan Ng Pag-Ibig
# 00mBzIWv5gHOYxwuEJXjOG  2019-09-02        39         Sa Ngalan Ng Pag-Ibig
# 00mBzIWv5gHOYxwuEJXjOG  2019-09-03        37         Sa Ngalan Ng Pag-Ibig
# 00mBzIWv5gHOYxwuEJXjOG  2019-09-04        35         Sa Ngalan Ng Pag-Ibig
# 00mBzIWv5gHOYxwuEJXjOG  2019-09-05        33         Sa Ngalan Ng Pag-Ibig
# ...                            ...       ...                           ...
# 7ytR5pFWmSjzHJIeQkgog4  2020-08-30        48  ROCKSTAR (feat. Roddy Ricch)
# 7ytR5pFWmSjzHJIeQkgog4  2020-08-31        52  ROCKSTAR (feat. Roddy Ricch)
# 7zFBtYAVURF3bUVqEQ6UUu  2019-09-01       161                           ICY
# 7zFBtYAVURF3bUVqEQ6UUu  2019-09-08       195                           ICY
# 7zFBtYAVURF3bUVqEQ6UUu  2019-09-15       185                           ICY
#
# ...

# %%
df4.reset_index(inplace=True)

# %%
df4.to_csv("C:/Users/knocom/Eskwelabs Jupyter Notebooks/Sprint 3/get_spotify_data-master/data/merged_charts_tracks_datav3.csv", index=False)
